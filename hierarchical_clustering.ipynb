# %%
# Standard libraries Imports
import json
# Third party Imports
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  
import umap.umap_ as umap
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA 
from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_samples, silhouette_score
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import linkage
# Local importss
from src.utils import count_plot_percentage
from src.utils import one_hot_encoding

# %%
data = pd.read_csv("data/Citywide_Mobility_Survey_-_Person_Survey_2019.csv")

# %%
data.head()
# Out:
#        hh_id     weight        cms_zone  survey_mode    person_id  person_num  \
# 0  191546322    0.00000  Inner Brooklyn            1  19154632203           3
# 1  191546322    0.00000  Inner Brooklyn            1  19154632202           2
# 2  191546322  212.12729  Inner Brooklyn            1  19154632201           1
# 3   19241657    0.00000   Middle Queens            1   1924165703           3
# 4   19241657    0.00000   Middle Queens            1   1924165702           2
#
#    is_participant  num_days  num_days_complete  num_trips  ...  \
# 0               0       NaN                NaN        NaN  ...
# 1               0       NaN                NaN        NaN  ...
# 2               1       7.0                7.0       23.0  ...
# 3               0       NaN                NaN        NaN  ...
# 4               0       NaN                NaN        NaN  ...
#
#    race_native_hawaiian  race_white  race_other  disability_hearing  \
# 0                   995         995         995                 995
# 1                   995         995         995                 995
# 2                     1           0           0                   0
# 3                   995         995         995                 995
# 4                   995         995         995                 995
#
#    disability_seeing  disability_walking  disability_mobility  \
# 0                995                 995                  995
# 1                995                 995                  995
# 2                  0                   0                    0
# 3                995                 995                  995
# 4                995                 995                  995
#
#   disability_dressing disability_concentrating  disability_none
# 0                 995                      995              995
# 1                 995                      995              995
# 2                   0                        0                1
# 3                 995                      995              995
# 4                 995                      995              995
#
# [5 rows x 165 columns]

# %% [markdown]
# * Observe having nominal data(categoricals represented by numbers). s.t. is_participant, race, and disability columns
# * Observe having NULL values

# %%
data.describe()
# Out:
#               hh_id        weight  survey_mode     person_id   person_num  \
# count  8.286000e+03   8286.000000  8286.000000  8.286000e+03  8286.000000
# mean   2.468398e+07    804.993000     1.246681  2.468398e+09     2.146633
# std    2.974500e+07   4395.258128     0.496917  2.974500e+09     1.317302
# min    1.900024e+07      0.000000     1.000000  1.900024e+09     1.000000
# 25%    1.926343e+07      0.000000     1.000000  1.926343e+09     1.000000
# 50%    1.951784e+07      0.000000     1.000000  1.951784e+09     2.000000
# 75%    1.979496e+07    199.885270     1.000000  1.979496e+09     3.000000
# max    1.999892e+08  88819.119060     3.000000  1.999892e+10    11.000000
#
#        is_participant     num_days  num_days_complete    num_trips  \
# count     8286.000000  3346.000000        3346.000000  3346.000000
# mean         0.403814     5.475792           4.334130    25.540646
# std          0.490691     2.612294           2.524525    21.900434
# min          0.000000     1.000000           1.000000     0.000000
# 25%          0.000000     1.000000           1.000000     4.000000
# 50%          0.000000     7.000000           5.000000    24.000000
# 75%          1.000000     7.000000           7.000000    41.000000
# max          1.000000     7.000000           7.000000   178.000000
#
#        num_walk_trips  ...  race_native_hawaiian   race_white   race_other  \
# count     3346.000000  ...           8286.000000  8286.000000  8286.000000
# mean        10.004782  ...            638.420468   638.613444   638.453295
# std         12.091553  ...            477.339270   477.081235   477.295392
# min          0.000000  ...              0.000000     0.000000     0.000000
# 25%          0.000000  ...              0.000000     1.000000     0.000000
# 50%          5.000000  ...            995.000000   995.000000   995.000000
# 75%         16.000000  ...            995.000000   995.000000   995.000000
# max         93.000000  ...            999.000000   999.000000   999.000000
#
#        disability_hearing  disability_seeing  disability_walking  \
# count         8286.000000        8286.000000         8286.000000
# mean           617.448467         617.443036          617.467053
# std            482.943289         482.950227          482.919543
# min              0.000000           0.000000            0.000000
# 25%              0.000000           0.000000            0.000000
# 50%            995.000000         995.000000          995.000000
# 75%            995.000000         995.000000          995.000000
# max            999.000000         999.000000          999.000000
#
#        disability_mobility  disability_dressing  disability_concentrating  \
# count          8286.000000          8286.000000               8286.000000
# mean            617.445571           617.442674                617.449071
# std             482.946990           482.950690                482.942518
# min               0.000000             0.000000                  0.000000
# 25%               0.000000             0.000000                  0.000000
# 50%             995.000000           995.000000                995.000000
# 75%             995.000000           995.000000                995.000000
# max             999.000000           999.000000                999.000000
#
#        disability_none
# count      8286.000000
# mean        617.774922
# std         482.525910
# min           0.000000
# 25%           1.000000
# 50%         995.000000
# 75%         995.000000
# max         999.000000
#
# [8 rows x 160 columns]

# %% [markdown]
# Though most of the features are nominal, but observe for quantitative data(jobs_count for example) that missing values, e.g., -9998 and 995, are affecting the results

# %%
# information about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8286 entries, 0 to 8285
# Columns: 165 entries, hh_id to disability_none
# dtypes: float64(20), int64(140), object(5)
# memory usage: 10.4+ MB

# %% [markdown]
# * Observe most of the values for 'work_park_amount_day', 'work_park_amount_week', 'work_park_amount_month' features are NULL
# * and 'work_cms_zone' have more than 60% NULLs
# * Observe 3 data types, will detect if we have more than these 3

# %%
data.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('float64'), dtype('O')], dtype=object)

# %% [markdown]
# * Observe having 'O' datatype, let's detect it

# %%
data.select_dtypes(include=['O']).columns
# Out:
# Index(['cms_zone', 'first_travel_date', 'last_travel_date', 'work_cms_zone',
#        'school_cms_zone'],
#       dtype='object')

# %%
data.select_dtypes(['O'])
# Out:
#             cms_zone first_travel_date last_travel_date  work_cms_zone  \
# 0     Inner Brooklyn        06/24/2019       06/30/2019            NaN
# 1     Inner Brooklyn        06/24/2019       06/30/2019            NaN
# 2     Inner Brooklyn        06/24/2019       06/30/2019            NaN
# 3      Middle Queens        05/29/2019       06/04/2019            NaN
# 4      Middle Queens        05/29/2019       06/04/2019            NaN
# ...              ...               ...              ...            ...
# 8281   Staten Island        06/15/2019       06/15/2019            NaN
# 8282   Staten Island        06/03/2019       06/03/2019  Staten Island
# 8283   Staten Island        06/03/2019       06/03/2019            NaN
# 8284   Staten Island        06/03/2019       06/03/2019            NaN
# 8285   Staten Island        06/03/2019       06/03/2019            NaN
#
#      school_cms_zone
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 8281             NaN
# 8282             NaN
# 8283             NaN
# 8284             NaN
# 8285             NaN
#
# [8286 rows x 5 columns]

# %%
data['cms_zone'].value_counts()
# Out:
# Northern Bronx        1032
# Staten Island         1024
# Outer Queens           975
# Southern Bronx         902
# Middle Queens          835
# Outer Brooklyn         822
# Inner Brooklyn         767
# Inner Queens           730
# Northern Manhattan     657
# Manhattan Core         542
# Name: cms_zone, dtype: int64

# %%
print(data['work_cms_zone'].value_counts().sum())
data['work_cms_zone'].value_counts()
# Out:
# 1687
# Manhattan Core     815
# Inner Brooklyn     166
# Southern Bronx     122
# Upper Manhattan    114
# Outer Brooklyn      96
# Inner Queens        79
# Middle Queens       75
# Staten Island       73
# Northern Bronx      70
# Outer Queens        69
# JFK                  7
# LGA                  1
# Name: work_cms_zone, dtype: int64

# %%
set(data['cms_zone']) - set(data['work_cms_zone'])
# Out:
# {'Northern Manhattan'}

# %%
set(data['work_cms_zone']) - set(data['cms_zone'])
# Out:
# {'JFK', 'LGA', 'Upper Manhattan', nan}

# %% [markdown]
# 'work_cms_zone' include more places than 'cms_zone'. e.g., 'JFK', 'LGA' airports

# %% [markdown]
# ### Employment
# * Detect employment status for majority of people
# * Detect employment status relationship with transportation method used

# %%
data["employment"].value_counts()
# Out:
# 1      3293
# 6      2185
# 995    1473
# 2       762
# 3       434
# 7       139
# Name: employment, dtype: int64

# %%
count_plot_percentage(data, 'employment')

# %% [markdown]
# * Most of the people are full-time paid employees
# * Quarter of people aren't currently employed (e.g., retired, looking for work)
# * Very few of people are volunteers or interns

# %%
count_plot_percentage(data, 'worker')

# %% [markdown]
# * 55.9% of people are employed. Almost the half
# * almost quarter of people aren't employed

# %%
data['jobs_count'].value_counts()
# Out:
#  995     5924
#  1       2031
#  2        231
#  3         57
#  6         17
# -9998      15
#  4          8
#  5          3
# Name: jobs_count, dtype: int64

# %%
data['job_type'].value_counts()
# Out:
#  995     5924
#  1       1627
#  2        497
#  3        135
#  4         88
# -9998      15
# Name: job_type, dtype: int64

# %% [markdown]
# Most usual work location for people is **one** work location, regardless of being a telework or onsite

# %%
data['industry'].value_counts().sort_values(ascending=False)
# Out:
#  995     5924
#  8        337
#  7        298
#  18       247
#  4        221
#  1        211
#  14       167
#  16       129
#  10       128
#  15       124
#  9        100
#  12        91
#  5         87
#  17        60
#  2         60
#  13        43
#  11        28
# -9998      15
#  6         13
#  3          3
# Name: industry, dtype: int64

# %% [markdown]
# * Most of them Missing: Skip logic
# * Only 3 of them their work industry is: Capital goods (aerospace & defense, electrical, machinery)
# * Most work industry in which people work in is: Health care/social assistance

# %%
count_plot_percentage(data, 'drive_cbd_freq')

# %% [markdown]
# Regardless of 995(Missing: Skip logic), The majority of people who filled out the survey are those with least Frequency of driving vehicle into or within the area of Manhattan south of 60th Street

# %%
count_plot_percentage(data, 'congestion')

# %% [markdown]
# Proportion of people opposing and supporting the congistion almost equal

# %%
# Observe wheter people's frequency of driving vehicle into or within the area of Manhattan south of 60th Street affects supporting/opposing congesiton
plt.figure(figsize=(20, 6))
sns.countplot(x='congestion', hue='drive_cbd_freq', data=data)
# Out:
# <AxesSubplot: xlabel='congestion', ylabel='count'>

# %% [markdown]
# No clear inferences, sounds that people who have never drived into or within Manhattan have alost equal voting with regard to congestion

# %%
data.groupby("congestion")["drive_cbd_freq"].value_counts()
# Out:
# congestion  drive_cbd_freq
# -9998       -9998               73
#              995                65
#  1           995               413
#              7                  87
#              8                  86
#              6                  30
#              4                   8
#              5                   8
#              2                   7
#              1                   3
#              3                   3
#  2           995               405
#              7                 150
#              8                 118
#              6                  50
#              5                  11
#              4                  10
#              2                   7
#              1                   4
#              3                   1
#  3           995               218
#              7                 107
#              8                  61
#              6                  37
#              5                  19
#              4                   9
#              1                   3
#              2                   3
#              3                   2
#  4           995               313
#              7                 238
#              8                 137
#              6                 114
#              4                  49
#              5                  46
#              2                  28
#              1                  14
#              3                   7
#  5           995               238
#              8                  97
#              7                  47
#              6                  12
#              4                   4
#              1                   2
#              5                   2
#  995         995              4940
# Name: drive_cbd_freq, dtype: int64

# %% [markdown]
# Expect that people with more telework frequency support congestion and vice versa, let's detect that

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x='telework_freq', hue='congestion', data=data)
# Out:
# <AxesSubplot: xlabel='telework_freq', ylabel='count'>

# %% [markdown]
# besides missing(skip logic), the majority voting is from people with no telework. Appear that most of them highly opposing congestion

# %%
count_plot_percentage(data, 'telework_freq')

# %% [markdown]
# As detected from previous plot, majority of them are those with no telework, and missing(skip logic)

# %%
data['bike_num_days'].value_counts()
# Out:
# 995    7007
# 0      1090
# 1        68
# 2        37
# 3        30
# 4        17
# 5        15
# 6        12
# 7        10
# Name: bike_num_days, dtype: int64

# %%
count_plot_percentage(data, 'bike_num_days')

# %% [markdown]
# Most of people don't ride a bike The whole week

# %%
# Detect Bike && unemployed
plt.figure(figsize=(20, 6))
sns.countplot(x='bike_num_days', hue='employment', data=data)
# Out:
# <AxesSubplot: xlabel='bike_num_days', ylabel='count'>

# %%
trip_data = data[['hh_id','weight','cms_zone','survey_mode','person_id','person_num','is_participant','num_days','num_days_complete','num_trips','num_walk_trips','num_transit_trips','num_bike_trips','num_taxi_trips','num_tnc_trips','num_complete_weekend_days','num_complete_weekdays','first_travel_date','last_travel_date','made_trips','smartphone_type',
             'relationship','age','employment','worker']]

# %%
# Check unique values for each feature
obj = trip_data.nunique()
for key,value in obj.iteritems():
    print(key,",",value)
# Out:
# hh_id , 3346
# weight , 2497
# cms_zone , 10
# survey_mode , 3
# person_id , 8286
# person_num , 11
# is_participant , 2
# num_days , 2
# num_days_complete , 7
# num_trips , 109
# num_walk_trips , 68
# num_transit_trips , 45
# num_bike_trips , 25
# num_taxi_trips , 11
# num_tnc_trips , 14
# num_complete_weekend_days , 3
# num_complete_weekdays , 6
# first_travel_date , 39
# last_travel_date , 40
# made_trips , 2
# smartphone_type , 5
# relationship , 10
# age , 11
# employment , 6
# worker , 3

# %%
trip_data.dtypes
# Out:
# hh_id                          int64
# weight                       float64
# cms_zone                      object
# survey_mode                    int64
# person_id                      int64
# person_num                     int64
# is_participant                 int64
# num_days                     float64
# num_days_complete            float64
# num_trips                    float64
# num_walk_trips               float64
# num_transit_trips            float64
# num_bike_trips               float64
# num_taxi_trips               float64
# num_tnc_trips                float64
# num_complete_weekend_days    float64
# num_complete_weekdays        float64
# first_travel_date             object
# last_travel_date              object
# made_trips                   float64
# smartphone_type                int64
# relationship                   int64
# age                            int64
# employment                     int64
# worker                         int64
# dtype: object

# %% [markdown]
# ##### hh_id & person_id will be removed, it provides no extra information about the data
# ##### first_travel_date and last_travel_date will be removed in this iteration, not clearly understandable yet
# ##### num_days and num_days_complete won't be included in this iteration, need more information about them

# %%
data.drop(['hh_id','person_id','weight','first_travel_date','last_travel_date','num_days','num_days_complete'],axis=1, inplace=True)

# %% [markdown]
# ##### only data when is_participant equals to 1 will be selected then drop the column, current information: not participant doesn't help in survey information, almost all data is null when is_participant equals to 0

# %%
data_when_is_participant_zero = data[data['is_participant'] == 0]

# %%
# check sum of nulls 
obj = data_when_is_participant_zero.isnull().sum()
obj.sort_values(ascending=False)
# Out:
# num_complete_weekend_days     4940
# num_taxi_trips                4940
# work_park_amount_week         4940
# work_park_amount_day          4940
# made_trips                    4940
#                               ...
# school_vehicle_pass_period       0
# school_park_location             0
# school_mode_own                  0
# school_mode                      0
# disability_none                  0
# Length: 158, dtype: int64

# %%
# data = data[data['is_participant'] == 1]

# %%
obj = data.nunique()
for key,value in obj.iteritems():
    print(key,",",value)
# Out:
# cms_zone , 10
# survey_mode , 3
# person_num , 11
# is_participant , 2
# num_trips , 109
# num_walk_trips , 68
# num_transit_trips , 45
# num_bike_trips , 25
# num_taxi_trips , 11
# num_tnc_trips , 14
# num_complete_weekend_days , 3
# num_complete_weekdays , 6
# made_trips , 2
# smartphone_type , 5
# relationship , 10
# age , 11
# employment , 6
# worker , 3
# student , 3
# license , 4
# vehicle , 10
# congestion , 7
# drive_cbd_freq , 10
# planning_apps , 10
# job_type , 6
# jobs_count , 8
# industry , 20
# telework_freq , 9
# work_cms_zone , 12
# missing_work_location , 2
# work_mode , 10
# work_mode_own , 5
# work_park_location , 6
# work_park_pay , 7
# work_vehicle_pass_period , 6
# work_park_amount_day , 11
# work_park_amount_week , 10
# work_park_amount_month , 16
# work_park_amount_year , 4
# work_mode_auto , 6
# work_mode_bus , 8
# work_mode_rail , 6
# work_mode_ferry , 3
# work_mode_taxi , 6
# work_mode_bike , 5
# work_bike_park , 8
# work_mode_scooter , 1
# work_scooter_park , 1
# school_type , 14
# school_cms_zone , 10
# missing_school_location , 2
# kid_accompany , 3
# school_mode , 12
# school_mode_own , 5
# school_park_location , 4
# school_vehicle_pass_period , 7
# school_park_amount_day , 7
# school_park_amount_month , 8
# school_park_amount_week , 5
# school_park_amount_year , 8
# school_mode_auto , 7
# school_mode_bus , 9
# school_mode_rail , 6
# school_mode_ferry , 2
# school_access , 8
# school_egress , 7
# school_mode_taxi , 5
# school_mode_bike , 3
# school_bike_park , 4
# school_mode_scooter , 1
# school_scooter_park , 1
# bike_freq , 8
# bike_num_days , 9
# bike_stolen , 4
# bike_purpose_errands , 4
# bike_purpose_transit , 4
# bike_purpose_recreation , 4
# bike_purpose_commute , 4
# bike_purpose_appointment , 4
# bike_purpose_other , 4
# no_bike_nyc_bike_lanes , 3
# no_bike_nyc_paving , 3
# no_bike_nyc_storage , 3
# no_bike_nyc_long_trips , 3
# no_bike_nyc_showers , 3
# no_bike_nyc_modes , 3
# no_bike_nyc_unable , 3
# no_bike_nyc_other , 3
# bike_share_citi_bike , 4
# bike_share_jump , 4
# bike_share_lime , 4
# bike_share_none , 4
# bike_share_user , 4
# citi_bike_freq , 9
# jump_freq , 7
# lime_freq , 6
# no_bike_share_unfamiliar , 4
# no_bike_share_expensive , 4
# no_bike_share_neighborhood , 4
# no_bike_share_stations , 4
# no_bike_share_personal_bike , 4
# no_bike_share_docks , 4
# no_bike_share_uncomfortable , 4
# no_bike_share_other , 4
# tnc_use_uber , 4
# tnc_use_lyft , 4
# tnc_use_via , 4
# tnc_use_juno , 4
# tnc_use_none , 4
# tnc_user , 4
# tnc_freq , 9
# tnc_purpose , 11
# tnc_mode , 11
# tnc_mode_auto , 7
# tnc_mode_taxi , 4
# tnc_mode_bus , 7
# tnc_mode_rail , 6
# tnc_mode_ferry , 3
# tnc_mode_bike , 4
# tnc_mode_scooter , 3
# car_share_zipcar , 4
# car_share_car2go , 4
# car_share_enterprise , 4
# car_share_other , 4
# car_share_none , 4
# car_share_user , 4
# packages , 10
# packages_distance , 7
# harassment , 6
# harassment_trip , 4
# harassment_time , 4
# harassment_route , 4
# harassment_transit , 4
# harassment_mode , 4
# harassment_neighborhood , 4
# harassment_private_car , 4
# harassment_alone , 4
# harassment_attention , 4
# harassment_defense , 4
# harassment_other , 4
# harassment_none , 4
# gender , 6
# education , 10
# english_proficiency , 6
# ethnicity , 7
# race_american_indian , 4
# race_asian , 4
# race_black , 4
# race_native_hawaiian , 4
# race_white , 4
# race_other , 4
# disability_hearing , 4
# disability_seeing , 4
# disability_walking , 4
# disability_mobility , 4
# disability_dressing , 4
# disability_concentrating , 4
# disability_none , 4

# %% [markdown]
# ##### as a result person_num and relationship feature will be deleted because they have on value

# %%
data.drop(['person_num','relationship'],axis=1,inplace=True)

# %%
trips_numerical_data = data[['num_trips','num_walk_trips','num_transit_trips','num_bike_trips','num_taxi_trips','num_tnc_trips','num_complete_weekend_days',
                      'num_complete_weekdays']]

# %%
trips_numerical_data.describe()
# Out:
#          num_trips  num_walk_trips  num_transit_trips  num_bike_trips  \
# count  3346.000000     3346.000000        3346.000000     3346.000000
# mean     25.540646       10.004782           5.827555        0.419307
# std      21.900434       12.091553           7.646751        2.141812
# min       0.000000        0.000000           0.000000        0.000000
# 25%       4.000000        0.000000           0.000000        0.000000
# 50%      24.000000        5.000000           2.000000        0.000000
# 75%      41.000000       16.000000          10.000000        0.000000
# max     178.000000       93.000000          57.000000       36.000000
#
#        num_taxi_trips  num_tnc_trips  num_complete_weekend_days  \
# count     3346.000000    3346.000000                3346.000000
# mean         0.111775       0.374776                   1.266886
# std          1.664201       1.181070                   0.843984
# min          0.000000       0.000000                   0.000000
# 25%          0.000000       0.000000                   0.000000
# 50%          0.000000       0.000000                   2.000000
# 75%          0.000000       0.000000                   2.000000
# max         92.000000      18.000000                   2.000000
#
#        num_complete_weekdays
# count            3346.000000
# mean                3.067244
# std                 1.858192
# min                 0.000000
# 25%                 1.000000
# 50%                 4.000000
# 75%                 5.000000
# max                 5.000000

# %% [markdown]
# ##### from the frequency matrix -columns features, rows values-
# ##### for example count of 1 of survey_mode is the most frequent which means people filled the survey by using rMove (smartphone app)
# ##### Northern Bronx is the most frequent cms_zone
# ##### Age values are between 5 and 11, which means 18yo and older
# ##### most answers from people has iphone mobile

# %%
# display correlation matrix between features
numeric_corr_matrix = trips_numerical_data.corr()
numeric_corr_matrix
# Out:
#                            num_trips  num_walk_trips  num_transit_trips  \
# num_trips                   1.000000        0.685732           0.574478
# num_walk_trips              0.685732        1.000000           0.610044
# num_transit_trips           0.574478        0.610044           1.000000
# num_bike_trips              0.162543        0.116651           0.009034
# num_taxi_trips              0.081621        0.021248           0.015657
# num_tnc_trips               0.187826        0.183317           0.135196
# num_complete_weekend_days   0.494895        0.428865           0.346632
# num_complete_weekdays       0.530072        0.468685           0.380096
#
#                            num_bike_trips  num_taxi_trips  num_tnc_trips  \
# num_trips                        0.162543        0.081621       0.187826
# num_walk_trips                   0.116651        0.021248       0.183317
# num_transit_trips                0.009034        0.015657       0.135196
# num_bike_trips                   1.000000        0.007480       0.062776
# num_taxi_trips                   0.007480        1.000000       0.033284
# num_tnc_trips                    0.062776        0.033284       1.000000
# num_complete_weekend_days        0.090722        0.036010       0.155752
# num_complete_weekdays            0.105136        0.036915       0.166960
#
#                            num_complete_weekend_days  num_complete_weekdays
# num_trips                                   0.494895               0.530072
# num_walk_trips                              0.428865               0.468685
# num_transit_trips                           0.346632               0.380096
# num_bike_trips                              0.090722               0.105136
# num_taxi_trips                              0.036010               0.036915
# num_tnc_trips                               0.155752               0.166960
# num_complete_weekend_days                   1.000000               0.703968
# num_complete_weekdays                       0.703968               1.000000

# %% [markdown]
# ##### NaN = no correlation between, they don't affect/change each other, propably going to be deleted --person_num--
# ##### regardless the change of person_num, num of trips kinds don't change

# %%
# Plot a correlation matrix for numeric features
sns.heatmap(numeric_corr_matrix, cmap='coolwarm')
plt.title('Correlation Matrix for Numeric Features')
plt.show()

# %%
categorical_data = data[['made_trips','smartphone_type','age','cms_zone','survey_mode']]

# %%
categorical_data['age'].unique()
# Out:
# array([ 9,  8,  5,  7,  6,  4,  3,  1,  2, 10, 11], dtype=int64)

# %%
# dropping age 1 (under 5) // data may be innaccurate
# data.drop(data[data['age'] == 1].index, inplace=True)

# %% [markdown]
# ##### See Frequency/Count for each value of the categorical features

# %%
categorical_frequency = categorical_data.apply(pd.Series.value_counts)
categorical_frequency
# Out:
#                     made_trips  smartphone_type     age  cms_zone  survey_mode
# 0.0                      309.0            377.0     NaN       NaN          NaN
# 1.0                     3037.0           1206.0   405.0       NaN       6495.0
# 2.0                        NaN           1747.0   871.0       NaN       1538.0
# 3.0                        NaN             16.0   197.0       NaN        253.0
# 4.0                        NaN              NaN   795.0       NaN          NaN
# 5.0                        NaN              NaN  1502.0       NaN          NaN
# 6.0                        NaN              NaN  1225.0       NaN          NaN
# 7.0                        NaN              NaN  1186.0       NaN          NaN
# 8.0                        NaN              NaN  1067.0       NaN          NaN
# 9.0                        NaN              NaN   696.0       NaN          NaN
# 10.0                       NaN              NaN   258.0       NaN          NaN
# 11.0                       NaN              NaN    84.0       NaN          NaN
# 995.0                      NaN           4940.0     NaN       NaN          NaN
# Inner Brooklyn             NaN              NaN     NaN     767.0          NaN
# Inner Queens               NaN              NaN     NaN     730.0          NaN
# Manhattan Core             NaN              NaN     NaN     542.0          NaN
# Middle Queens              NaN              NaN     NaN     835.0          NaN
# Northern Bronx             NaN              NaN     NaN    1032.0          NaN
# Northern Manhattan         NaN              NaN     NaN     657.0          NaN
# Outer Brooklyn             NaN              NaN     NaN     822.0          NaN
# Outer Queens               NaN              NaN     NaN     975.0          NaN
# Southern Bronx             NaN              NaN     NaN     902.0          NaN
# Staten Island              NaN              NaN     NaN    1024.0          NaN

# %%
categorical_data['cms_zone'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
school_numerical_data = data[['school_park_amount_day','school_park_amount_week','school_park_amount_month','school_park_amount_year']]

# %%
school_categorical_data = data[['student','license','vehicle','congestion','school_type','school_cms_zone',
                                       'missing_school_location','kid_accompany','school_mode','school_mode_own','school_park_location',
                                       'school_vehicle_pass_period', 'school_mode_auto', 'school_mode_bus','school_mode_rail', 'school_mode_ferry', 'school_access',
                                       'school_egress', 'school_mode_taxi', 'school_mode_bike','school_bike_park', 'school_mode_scooter', 'school_scooter_park']]

# %%
# Plot a scatter plot of two features
plt.scatter(data['student'], data['age'])
plt.title('Scatter Plot of age and sudent')
plt.xlabel('student Values')
plt.ylabel('age Values')
plt.show()

# %%
data[data['student'] == 1]['age'].unique()
# Out:
# array([ 5,  3,  1,  2,  4,  6,  7,  8,  9, 10], dtype=int64)

# %%
data.loc[data['student'] == 1]['age'].unique()
# Out:
# array([ 5,  3,  1,  2,  4,  6,  7,  8,  9, 10], dtype=int64)

# %% [markdown]
# #### from the plot
# ##### not students age varies between 4(18-24) and 11(85 or older)
# ##### full time student age varies between 1(Under 5) //dropped and 10(75-84)
# ##### half-time student age varies between 4(18-24) and 9(65-74)

# %%
school_categorical_data['school_cms_zone'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ##### Manhattan Core has the highest number of school

# %%
school_categorical_data['congestion'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ##### high number of people don't agree with the policy of congestion pricing (4)

# %%
school_numerical_data.describe()
# Out:
#        school_park_amount_day  school_park_amount_week  \
# count                7.000000                 5.000000
# mean                 7.892857                21.050000
# std                  6.177677                28.202615
# min                  0.250000                 0.250000
# 25%                  3.000000                 4.000000
# 50%                  8.000000                15.000000
# 75%                 12.500000                16.000000
# max                 16.000000                70.000000
#
#        school_park_amount_month  school_park_amount_year
# count                  8.000000                 8.000000
# mean                  23.781250               128.156250
# std                   21.036294               161.335882
# min                    0.250000                 0.250000
# 25%                   12.250000                12.250000
# 50%                   18.000000                53.000000
# 75%                   31.250000               212.500000
# max                   60.000000               450.000000

# %%
# display correlation matrix between features
numeric_corr_matrix = school_numerical_data.corr()
numeric_corr_matrix
# Out:
#                           school_park_amount_day  school_park_amount_week  \
# school_park_amount_day                       1.0                      1.0
# school_park_amount_week                      1.0                      1.0
# school_park_amount_month                     1.0                      1.0
# school_park_amount_year                      1.0                      1.0
#
#                           school_park_amount_month  school_park_amount_year
# school_park_amount_day                         1.0                      1.0
# school_park_amount_week                        1.0                      1.0
# school_park_amount_month                       1.0                      1.0
# school_park_amount_year                        1.0                      1.0

# %%
# Plot a correlation matrix for numeric features
sns.heatmap(numeric_corr_matrix, cmap='coolwarm')
plt.title('Correlation Matrix for Numeric Features')
plt.show()

# %% [markdown]
# ##### Strong Correlated

# %%
harassment_data = data[['harassment','harassment_private_car', 'harassment_alone', 'harassment_attention',
       'harassment_defense', 'harassment_other', 'harassment_none', 'gender',
       'education', 'english_proficiency', 'ethnicity', 'race_american_indian',
       'race_asian', 'race_black', 'race_native_hawaiian', 'race_white',
       'race_other', 'disability_hearing', 'disability_seeing',
       'disability_walking', 'disability_mobility', 'disability_dressing',
       'disability_concentrating', 'disability_none']]

# %%
harassment_data['harassment'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ##### most haven't seen or experienced harassment (4)

# %%
# Plot a scatter plot of two features
plt.scatter(harassment_data['harassment'], harassment_data['ethnicity'])
plt.title('Scatter Plot of harassment and ethnicity')
plt.xlabel('harassment Values')
plt.ylabel('ethnicity Values')
plt.ylim(0,5)
plt.xlim(0,5)
plt.show()

# %% [markdown]
# ##### all have seen and/or experienced harassment, and mexican people seem to experience it the most

# %%
plt.scatter(harassment_data['harassment'], harassment_data['gender'])
plt.title('Scatter Plot of harassment and gender')
plt.xlabel('harassment Values')
plt.ylabel('gender Values')
plt.ylim(0,5)
plt.xlim(0,5)
plt.show()

# %% [markdown]
# ##### all genders are equal

# %%
plt.scatter(harassment_data['harassment'], harassment_data['disability_seeing'])
plt.title('Scatter Plot of harassment and disability_seeing')
plt.xlabel('harassment Values')
plt.ylabel('disability_seeing Values')
plt.ylim(0,5)
plt.xlim(0,5)
plt.show()

# %% [markdown]
# ##### disabilities doesn't really affect

# %%
plt.scatter(harassment_data['harassment'], harassment_data['race_black'])
plt.title('Scatter Plot of harassment and race_black')
plt.xlabel('harassment Values')
plt.ylabel('race_black Values')
plt.ylim(0,5)
plt.xlim(0,5)
plt.show()

# %% [markdown]
# ##### black or other doesn't affect

# %%
plt.scatter(harassment_data['harassment'], harassment_data['english_proficiency'])
plt.title('Scatter Plot of harassment and english_proficiency')
plt.xlabel('harassment Values')
plt.ylabel('english_proficiency Values')
plt.ylim(0,5)
plt.xlim(0,5)
plt.show()

# %% [markdown]
# ##### who speaks english well got harassment

# %%
package_data = data[['packages','packages_distance']]

# %%
package_frequency = package_data.apply(pd.Series.value_counts)
package_frequency
# Out:
#        packages  packages_distance
# -9998       234                NaN
#  1          696               44.0
#  2         1283               98.0
#  3          312              161.0
#  4          163               93.0
#  5          152               29.0
#  6          150               40.0
#  7          163                NaN
#  8          193                NaN
#  995       4940             7821.0

# %%
package_data['packages'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### most people recieve their packages at their doorsteps

# %%
package_data['packages_distance'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### most people move 3 blocks away ((around neighbourhood)) to get their packages
# ###### 1 block = 15 meters

# %%
numerical_data= pd.concat([trips_numerical_data,school_numerical_data],axis=1)

# %%
numerical_data['school_park_amount_year'].unique()
# Out:
# array([    nan, 9.0e+01, 4.5e+02, 2.5e+02, 2.0e+02, 2.5e-01, 4.0e+00,
#        1.6e+01, 1.5e+01])

# %%
#plots help us to decide what to do in feature engineering
def plots_(data,feature): 
        fig, ax = plt.subplots(1, figsize=(10,10), sharey=True)
        fig.suptitle(feature, fontsize=14)
        sns.distplot(data[feature], ax=ax)
        plt.show()

for column in numerical_data:
    feature=plots_(numerical_data, column)
# Out:
# C:\Users\danar\AppData\Local\Temp\ipykernel_12416\2273597600.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[feature], ax=ax)
# C:\Users\danar\AppData\Local\Temp\ipykernel_12416\2273597600.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[feature], ax=ax)
# C:\Users\danar\AppData\Local\Temp\ipykernel_12416\2273597600.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[feature], ax=ax)
# C:\Users\danar\AppData\Local\Temp\ipykernel_12416\2273597600.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[feature], ax=ax)
# C:\Users\danar\AppData\Local\Temp\ipykernel_12416\2273597600.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[feature], ax=ax)
# C:\Users\danar\AppData\Local\Temp\ipykernel_12416\2273597600.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[feature], ax=ax)
# C:\Users\danar\AppData\Local\Temp\ipykernel_12416\2273597600.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[feature], ax=ax)
# C:\Users\danar\AppData\Local\Temp\ipykernel_12416\2273597600.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[feature], ax=ax)
# C:\Users\danar\AppData\Local\Temp\ipykernel_12416\2273597600.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[feature], ax=ax)
# C:\Users\danar\AppData\Local\Temp\ipykernel_12416\2273597600.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[feature], ax=ax)
# C:\Users\danar\AppData\Local\Temp\ipykernel_12416\2273597600.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[feature], ax=ax)
# C:\Users\danar\AppData\Local\Temp\ipykernel_12416\2273597600.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[feature], ax=ax)

# %% [markdown]
# ##### skewed data such as ['num_walk_trips', 'num_transit_trips','num_bike_trips','num_taxi_trips','num_tnc_trips'] will be log transformed to reduce skewness before scaling
# ##### bimodal distribution ['num_trips','school_park_amount_weak' ,'school_park_amount_month'] normalization or standardization can be applied
# ##### multimodal distribution ['num_complete_weekdays', 'num_complete_weekend_days'] normalization or standardization can be applied

# %% [markdown]
# # Missing Values

# %% [markdown]
# convert the -9998 value to NaN to handle it also with missing values

# %%
for column in data.columns:
    data[column] = data[column].replace(-9998,np.nan)
    data[column] = data[column].replace("-9998",np.nan)

# %% [markdown]
# compute the percentage of null values of each column

# %%
null_percentage = data.isna().sum().apply(lambda x:x/data.shape[0]*100).sort_values(ascending=False)[data.isna().sum()>0]

# %%
null_percentage.plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# remove any column have more than 50% NULL

# %%
print(f"before Remove  {data.shape}")
data.drop(columns=null_percentage[null_percentage>50].index.to_list(),inplace=True)
print(f"after Remove  {data.shape}")
# Out:
# before Remove  (8286, 156)
# after Remove  (8286, 137)

# %% [markdown]
# for the rest we will remove any row have null value

# %%
print(f"before Remove  {data.shape}")
data = data.dropna(axis=0)
print(f"after Remove  {data.shape}")
# Out:
# before Remove  (8286, 137)
# after Remove  (6728, 137)

# %% [markdown]
# remove any row have is_participant value not 1 becouse all the rest of the values are null

# %%
print(f"before Remove  {data.shape}")
data = data[data["is_participant"]==1]
print(f"after Remove  {data.shape}")
# Out:
# before Remove  (6728, 137)
# after Remove  (2692, 137)

# %% [markdown]
# # Encoding Features

# %%
with open("data/columns_encoding.json") as file:
    columns_dictionary = json.loads(file.read()) # read the file as string and convert it to dictionary

# %%
columns_dictionary
# Out:
# {'survey_mode': {'1': 'rMove',
#   '2': 'rSurvey',
#   '3': 'Call center',
#   '995': 'skip logic'},
#  'is_participant': {'0': 'Not selected', '1': 'Selected', '995': 'skip logic'},
#  'made_trips': {'0': 'Not selected', '1': 'Selected', '995': 'skip logic'},
#  'relationship': {'0': 'Self',
#   '1': 'Spouse or partner',
#   '2': 'Son or daughter',
#   '3': 'Father or mother',
#   '4': 'Brother or sister',
#   '5': 'Other relative',
#   '6': 'Roommate or friend',
#   '7': 'Household help',
#   '995': 'skip logic'},
#  'age': {'1': 'Under 5',
#   '2': '5-15',
#   '3': '16-17',
#   '4': '18-24',
#   '5': '25-34',
#   '6': '35-44',
#   '7': '45-54',
#   '8': '55-64',
#   '9': '65-74',
#   '10': '75-84',
#   '11': '85 or older',
#   '995': 'skip logic'},
#  'employment': {'1': 'Employed full-time',
#   '2': 'Employed part-time',
#   '3': 'Primarily self-employed',
#   '6': 'Not currently employed',
#   '7': 'Unpaid volunteer or intern',
#   '995': 'skip logic'},
#  'worker': {'0': 'Not employed', '1': 'Employed', '995': 'skip logic'},
#  'student': {'0': 'Not a student',
#   '1': 'Full-time student',
#   '2': 'Part-time student',
#   '995': 'skip logic'},
#  'license': {'0': 'No', '1': 'Yes', '995': 'skip logic'},
#  'vehicle': {'1': 'HH vehicle 1',
#   '2': 'HH vehicle 2',
#   '3': 'HH vehicle 3',
#   '4': 'HH vehicle 4',
#   '5': 'HH vehicle 5',
#   '6': 'HH vehicle 6',
#   '7': 'HH vehicle 7',
#   '8': 'HH vehicle 8',
#   '18': 'A carshare vehicle',
#   '996': 'None',
#   '997': 'Other',
#   '995': 'skip logic'},
#  'congestion': {'1': 'Strongly support',
#   '2': 'Somewhat support',
#   '3': 'Somewhat oppose',
#   '4': 'Strongly oppose',
#   '5': 'No opinion',
#   '995': 'skip logic'},
#  'drive_cbd_freq': {'1': '6-7 days a week',
#   '2': '5 days a week',
#   '3': '4 days a week',
#   '4': '2-3 days a week',
#   '5': '1 day a week',
#   '6': '1-3 days a month',
#   '7': 'Less than monthly',
#   '8': 'Never',
#   '995': 'skip logic'},
#  'planning_apps': {'1': '6-7 days a week',
#   '2': '5 days a week',
#   '3': '4 days a week',
#   '4': '2-3 days a week',
#   '5': '1 day a week',
#   '6': '1-3 days a month',
#   '7': 'Less than monthly',
#   '8': 'Never',
#   '995': 'skip logic'},
#  'job_type': {'1': 'Only one work location',
#   '2': 'Work location regularly varies',
#   '3': 'Work remotely or from home ONLY',
#   '995': 'skip logic'},
#  'industry': {'1': 'Financial services',
#   '2': 'Real estate',
#   '3': 'Capital goods',
#   '4': 'Professional and business services',
#   '5': 'Hospitality',
#   '6': 'Energy',
#   '7': 'Education',
#   '8': 'Health',
#   '9': 'Arts and entertainment',
#   '10': 'Retail',
#   '11': 'Manufacturing',
#   '12': 'Transportation and utilities',
#   '13': 'Construction',
#   '14': 'Government',
#   '15': 'Non-profit',
#   '16': 'Technology and telecommunications',
#   '17': 'Media',
#   '18': 'Other',
#   '995': 'skip logic'},
#  'telework_freq': {'1': '6-7 days a week',
#   '2': '5 days a week',
#   '3': '4 days a week',
#   '4': '2-3 days a week',
#   '5': '1 day a week',
#   '6': '1-3 days a month',
#   '7': 'Less than monthly',
#   '8': 'Never',
#   '995': 'skip logic'},
#  'missing_work_location': {'0': 'No', '1': 'Yes', '995': 'skip logic'},
#  'work_mode': {'5': 'Other',
#   '100': 'In a household vehicle',
#   '101': 'In other personal vehicle',
#   '102': 'Any bus or shuttle',
#   '103': 'Bicycle',
#   '104': 'Ferry',
#   '105': 'Any rail',
#   '106': 'Any taxi or ride service',
#   '995': 'skip logic'},
#  'work_mode_own': {'6': 'HH vehicle 1',
#   '7': 'HH vehicle 2',
#   '8': 'HH vehicle 3',
#   '16': 'Other vehicle in household',
#   '47': 'Other motorcycle',
#   '995': 'skip logic'},
#  'work_park_location': {'3': 'Parking',
#   '4': 'On street parking',
#   '7': 'Other',
#   '995': 'skip logic'},
#  'work_park_pay': {'1': 'Parking is always free',
#   '2': 'Employer pays ALL parking costs',
#   '3': 'Employer offers discounted parking',
#   '4': 'I personally pay some or all parking costs with a pre-tax transportation card',
#   '5': 'I personally pay some or all parking costs',
#   '995': 'skip logic'},
#  'work_vehicle_pass_period': {'1': 'Per',
#   '2': 'Per',
#   '3': 'Per',
#   '4': 'Per',
#   '995': 'skip logic'},
#  'work_mode_auto': {'17': 'Rental car',
#   '18': 'Carshare service',
#   '22': 'Other vehicle',
#   '33': 'Car from work',
#   '76': 'Carpool',
#   '995': 'skip logic'},
#  'work_mode_bus': {'21': 'Commuter Van',
#   '23': 'Local bus',
#   '25': 'Intercity bus',
#   '26': 'Other private',
#   '28': 'Other bus',
#   '38': 'University',
#   '55': 'Express bus',
#   '61': 'Select Bus Service',
#   '62': 'Employer',
#   '995': 'skip logic'},
#  'work_mode_rail': {'30': 'Subway',
#   '41': 'Intercity rail',
#   '42': 'Other rail',
#   '58': 'Commuter rail',
#   '110': 'PATH train',
#   '995': 'skip logic'},
#  'work_mode_ferry': {'111': 'Staten Island Ferry',
#   '112': 'NYC Ferry',
#   '113': 'Other',
#   '995': 'skip logic'},
#  'work_mode_taxi': {'36': 'Yellow taxi',
#   '60': 'Other hired car service',
#   '108': 'Green taxi',
#   '995': 'skip logic'},
#  'work_mode_bike': {'2': 'Standard bicycle owned by my household',
#   '3': 'Borrowed bicycle',
#   '78': 'Pedal-assist bicycle owned by my household',
#   '79': 'Citi Bike',
#   '80': 'Citi Bike',
#   '81': 'Dockless bike share',
#   '82': 'Dockless bike share',
#   '83': 'Other rented bicycle',
#   '995': 'skip logic'},
#  'work_bike_park': {'2': 'Bike rack',
#   '3': 'Bike locker',
#   '4': 'Secured bike room',
#   '5': 'Locked to other object',
#   '6': 'Bike-share designated docking station',
#   '7': 'Unlocked on-street',
#   '8': 'Other',
#   '10': 'In a parking',
#   '995': 'skip logic'},
#  'work_mode_scooter': {'73': 'Moped share',
#   '75': 'Other moped or scooter',
#   '77': 'Personal scooter or moped',
#   '995': 'skip logic'},
#  'work_scooter_park': {'3': 'Locker for',
#   '4': 'Secured room',
#   '5': 'Locked to other object',
#   '6': 'Moped-share designated docking station',
#   '7': 'Unlocked on-street',
#   '8': 'Other',
#   '10': 'In a parking',
#   '995': 'skip logic'},
#  'school_type': {'1': 'Cared for at home',
#   '2': 'Daycare outside home',
#   '3': 'Preschool',
#   '4': 'Home school',
#   '5': 'Elementary school',
#   '6': 'Middle school',
#   '7': 'High school',
#   '9': '2-year',
#   '10': '4-year',
#   '11': 'Graduate or professional school',
#   '995': 'skip logic'},
#  'missing_school_location': {'0': 'No', '1': 'Yes', '995': 'skip logic'},
#  'kid_accompany': {'0': 'No', '1': 'Yes', '995': 'skip logic'},
#  'school_mode': {'5': 'Other',
#   '100': 'In a household vehicle',
#   '101': 'In other personal vehicle',
#   '102': 'Any bus or shuttle',
#   '103': 'Bicycle',
#   '104': 'Ferry',
#   '105': 'Any rail',
#   '106': 'Any taxi or ride service',
#   '996': 'Take online classes',
#   '995': 'skip logic'},
#  'school_mode_own': {'6': 'HH vehicle 1',
#   '7': 'HH vehicle 2',
#   '8': 'HH vehicle 3',
#   '16': 'Other vehicle in household',
#   '47': 'Other motorcycle',
#   '995': 'skip logic'},
#  'school_park_location': {'3': 'Parking',
#   '4': 'On street parking',
#   '7': 'Other',
#   '995': 'skip logic'},
#  'school_vehicle_pass_period': {'1': 'Per',
#   '2': 'Per',
#   '3': 'Per',
#   '4': 'Per',
#   '5': 'Parking is',
#   '995': 'skip logic'},
#  'school_mode_auto': {'17': 'Rental car',
#   '18': 'Carshare service',
#   '22': 'Other vehicle',
#   '33': 'Car from work',
#   '76': 'Carpool',
#   '995': 'skip logic'},
#  'school_mode_bus': {'21': 'Commuter Van',
#   '23': 'Local bus',
#   '24': 'School bus',
#   '25': 'Intercity bus',
#   '26': 'Other private',
#   '28': 'Other bus',
#   '38': 'University',
#   '55': 'Express bus',
#   '61': 'Select Bus Service',
#   '995': 'skip logic'},
#  'school_mode_rail': {'30': 'Subway',
#   '41': 'Intercity rail',
#   '42': 'Other rail ',
#   '58': 'Commuter rail',
#   '110': 'PATH train',
#   '995': 'skip logic'},
#  'school_mode_ferry': {'111': 'Staten Island Ferry',
#   '112': 'NYC Ferry',
#   '113': 'Other',
#   '995': 'skip logic'},
#  'school_access': {'2': 'Personal bicycle',
#   '3': 'Bike share',
#   '5': 'Taxi',
#   '6': 'Smartphone-app ride service',
#   '7': 'Household vehicle',
#   '8': 'Other vehicle',
#   '995': 'skip logic'},
#  'school_egress': {'2': 'Personal bicycle',
#   '3': 'Bike share',
#   '5': 'Taxi',
#   '6': 'Smartphone-app ride service',
#   '7': 'Household vehicle',
#   '8': 'Other vehicle',
#   '995': 'skip logic'},
#  'school_mode_taxi': {'36': 'Yellow taxi',
#   '60': 'Other hired car service',
#   '108': 'Green taxi',
#   '995': 'skip logic'},
#  'school_mode_bike': {'2': 'Standard bicycle owned by my household',
#   '3': 'Borrowed bicycle',
#   '78': 'Pedal-assist bicycle owned by my household',
#   '79': 'Citi Bike',
#   '80': 'Citi Bike',
#   '81': 'Dockless bike share',
#   '82': 'Dockless bike share',
#   '83': 'Other rented bicycle',
#   '995': 'skip logic'},
#  'school_bike_park': {'2': 'Bike rack',
#   '3': 'Bike locker',
#   '4': 'Secured bike room',
#   '5': 'Locked to other object',
#   '6': 'Bike-share designated docking station',
#   '7': 'Unlocked on-street',
#   '8': 'Other',
#   '10': 'In a parking',
#   '995': 'skip logic'},
#  'school_mode_scooter': {'73': 'Moped share',
#   '75': 'Other moped or scooter',
#   '77': 'Personal scooter or moped',
#   '995': 'skip logic'},
#  'school_scooter_park': {'3': 'Locker for',
#   '4': 'Secured room',
#   '5': 'Locked to other object',
#   '6': 'Moped-share designated docking station',
#   '7': 'Unlocked on-street',
#   '8': 'Other',
#   '10': 'In a parking',
#   '995': 'skip logic'},
#  'bike_freq': {'1': 'Once a week or more',
#   '2': 'Several times a month',
#   '3': 'At least once a month',
#   '4': 'A few times a year',
#   '5': 'Never',
#   '6': 'Physically unable to ride a bike',
#   '995': 'skip logic'},
#  'bike_stolen': {'0': 'No', '1': 'Yes', '995': 'skip logic'},
#  'bike_purpose_errands': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'bike_purpose_transit': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'bike_purpose_recreation': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'bike_purpose_commute': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'bike_purpose_appointment': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'bike_purpose_other': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'no_bike_nyc_bike_lanes': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'no_bike_nyc_paving': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'no_bike_nyc_storage': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'no_bike_nyc_long_trips': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'no_bike_nyc_showers': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'no_bike_nyc_modes': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'no_bike_nyc_unable': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'no_bike_nyc_other': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'bike_share_citi_bike': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'bike_share_jump': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'bike_share_lime': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'bike_share_none': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'bike_share_user': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'citi_bike_freq': {'1': '6-7 days a week',
#   '2': '5 days a week',
#   '3': '4 days a week',
#   '4': '2-3 days a week',
#   '5': '1 day a week',
#   '6': '1-3 days a month',
#   '7': 'Less than monthly',
#   '8': 'Never',
#   '995': 'skip logic'},
#  'jump_freq': {'1': '6-7 days a week',
#   '2': '5 days a week',
#   '3': '4 days a week',
#   '4': '2-3 days a week',
#   '5': '1 day a week',
#   '6': '1-3 days a month',
#   '7': 'Less than monthly',
#   '8': 'Never',
#   '995': 'skip logic'},
#  'lime_freq': {'1': '6-7 days a week',
#   '2': '5 days a week',
#   '3': '4 days a week',
#   '4': '2-3 days a week',
#   '5': '1 day a week',
#   '6': '1-3 days a month',
#   '7': 'Less than monthly',
#   '8': 'Never',
#   '995': 'skip logic'},
#  'no_bike_share_unfamiliar': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'no_bike_share_expensive': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'no_bike_share_neighborhood': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'no_bike_share_stations': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'no_bike_share_personal_bike': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'no_bike_share_docks': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'no_bike_share_uncomfortable': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'no_bike_share_other': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'tnc_use_uber': {'0': 'Not selected', '1': 'Selected', '995': 'skip logic'},
#  'tnc_use_lyft': {'0': 'Not selected', '1': 'Selected', '995': 'skip logic'},
#  'tnc_use_via': {'0': 'Not selected', '1': 'Selected', '995': 'skip logic'},
#  'tnc_use_juno': {'0': 'Not selected', '1': 'Selected', '995': 'skip logic'},
#  'tnc_use_none': {'0': 'Not selected', '1': 'Selected', '995': 'skip logic'},
#  'tnc_user': {'0': 'Not selected', '1': 'Selected', '995': 'skip logic'},
#  'tnc_freq': {'1': '6-7 days a week',
#   '2': '5 days a week',
#   '3': '4 days a week',
#   '4': '2-3 days a week',
#   '5': '1 day a week',
#   '6': '1-3 days a month',
#   '7': 'Less than monthly',
#   '8': 'Never',
#   '995': 'skip logic'},
#  'tnc_purpose': {'1': 'Go home',
#   '2': 'Go to',
#   '3': 'Attended',
#   '5': 'Drop',
#   '50': 'Dine',
#   '51': 'Exercise',
#   '60': 'Go',
#   '99': 'Other reason',
#   '995': 'skip logic'},
#  'tnc_mode': {'5': 'Other',
#   '100': 'In a household vehicle',
#   '101': 'In other personal vehicle',
#   '102': 'Any bus or shuttle',
#   '103': 'Bicycle',
#   '104': 'Ferry',
#   '105': 'Any rail',
#   '106': 'Any taxi or car service',
#   '995': 'skip logic'},
#  'tnc_mode_auto': {'17': 'Rental car',
#   '18': 'Carshare service',
#   '22': 'Other vehicle',
#   '33': 'Car from work',
#   '76': 'Carpool',
#   '995': 'skip logic'},
#  'tnc_mode_taxi': {'36': 'Yellow taxi',
#   '60': 'Other hired car service',
#   '108': 'Green taxi',
#   '995': 'skip logic'},
#  'tnc_mode_bus': {'21': 'Commuter Van',
#   '23': 'Local bus',
#   '25': 'Intercity bus',
#   '26': 'Other private',
#   '28': 'Other bus',
#   '38': 'University',
#   '55': 'Express bus',
#   '61': 'Select Bus Service',
#   '62': 'Employer',
#   '995': 'skip logic'},
#  'tnc_mode_rail': {'30': 'Subway',
#   '41': 'Intercity rail',
#   '42': 'Other rail',
#   '58': 'Commuter rail',
#   '110': 'PATH train',
#   '995': 'skip logic'},
#  'tnc_mode_ferry': {'111': 'Staten Island Ferry',
#   '112': 'NYC Ferry',
#   '113': 'Other',
#   '995': 'skip logic'},
#  'tnc_mode_bike': {'2': 'Standard bicycle owned by my household',
#   '3': 'Borrowed bicycle',
#   '78': 'Pedal-assist bicycle owned by my household',
#   '79': 'Citi Bike',
#   '80': 'Citi Bike',
#   '81': 'Dockless bike share',
#   '82': 'Dockless bike share',
#   '83': 'Other rented bicycle',
#   '995': 'skip logic'},
#  'tnc_mode_scooter': {'73': 'Moped share',
#   '75': 'Other',
#   '77': 'Personal scooter or moped',
#   '995': 'skip logic'},
#  'car_share_zipcar': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'car_share_car2go': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'car_share_enterprise': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'car_share_other': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'car_share_none': {'0': 'Not selected', '1': 'Selected', '995': 'skip logic'},
#  'car_share_user': {'0': 'Not selected', '1': 'Selected', '995': 'skip logic'},
#  'packages': {'1': 'My lobby',
#   '2': 'My doorstep',
#   '3': 'My doorman',
#   '4': 'A postal store',
#   '5': 'An alternative address',
#   '6': 'An alternative access point',
#   '7': 'My workplace',
#   '8': 'Other',
#   '995': 'skip logic'},
#  'packages_distance': {'1': 'Less than 1 block',
#   '2': '1-2 blocks',
#   '3': '3-5 blocks',
#   '4': '6-10 blocks',
#   '5': '11-20 blocks',
#   '6': 'More than 20 blocks',
#   '995': 'skip logic'},
#  'harassment': {'1': 'I have seen',
#   '2': 'I have experienced',
#   '3': 'I have both seen and experienced',
#   '4': 'I have not seen or experienced',
#   '995': 'skip logic'},
#  'harassment_trip': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'harassment_time': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'harassment_route': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'harassment_transit': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'harassment_mode': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'harassment_neighborhood': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'harassment_private_car': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'harassment_alone': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'harassment_attention': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'harassment_defense': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'harassment_other': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'harassment_none': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'gender': {'1': 'Female',
#   '2': 'Male',
#   '4': 'Non-binary',
#   '999': 'Prefer not to',
#   '995': 'skip logic'},
#  'education': {'1': 'Less than high school',
#   '2': 'High school',
#   '3': 'Some college',
#   '5': 'Associate degree',
#   '999': 'Prefer not to',
#   '995': 'skip logic'},
#  'english_proficiency': {'1': 'Very well',
#   '2': 'Well',
#   '3': 'Not well',
#   '4': 'Not at all',
#   '995': 'skip logic'},
#  'ethnicity': {'999': 'Prefer not to', '995': 'skip logic'},
#  'race_american_indian': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'race_asian': {'0': 'Not selected', '1': 'Selected', '995': 'skip logic'},
#  'race_black': {'0': 'Not selected', '1': 'Selected', '995': 'skip logic'},
#  'race_native_hawaiian': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'race_white': {'0': 'Not selected', '1': 'Selected', '995': 'skip logic'},
#  'race_other': {'0': 'Not selected', '1': 'Selected', '995': 'skip logic'},
#  'disability_hearing': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'disability_seeing': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'disability_walking': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'disability_mobility': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'disability_dressing': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'disability_concentrating': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'},
#  'disability_none': {'0': 'Not selected',
#   '1': 'Selected',
#   '995': 'skip logic'}}

# %% [markdown]
# for each column_name in the dictionary encode the data using the dictionary values to create one_hot_encoding

# %%
for column_name in columns_dictionary:
    data = one_hot_encoding(data=data,column=column_name,dictionary=columns_dictionary[column_name])

# %%
data.dtypes.unique()
# Out:
# array([dtype('O'), dtype('int64'), dtype('float64'), dtype('uint8')],
#       dtype=object)

# %%
data.select_dtypes(include='object').columns # will handle it later
# Out:
# Index(['cms_zone'], dtype='object')

# %% [markdown]
# select numberic features only to apply kmeans on them

# %%
numeric_fetures = data.select_dtypes(include=np.number).columns.tolist()
data_numeric = data[numeric_fetures]
data_numeric.shape
# Out:
# (2692, 285)

# %% [markdown]
# apply Standard Scaler on the Data

# %%
data_numeric_standarized = StandardScaler().fit_transform(data_numeric)
data_numeric_standarized = pd.DataFrame(data_numeric_standarized, columns = data_numeric.columns)
data_numeric_standarized.head()
# data_numeric_standarized = data_numeric
# Out:
#    smartphone_type  jobs_count  bike_num_days  survey_mode_Call center  \
# 0        -0.507334    1.449614      -1.182246                -0.252213
# 1         0.873600   -0.690243      -1.186326                -0.252213
# 2         0.873600   -0.690243      -1.186326                -0.252213
# 3         0.873600   -0.690243      -1.176126                -0.252213
# 4        -0.507334   -0.688090       0.843432                -0.252213
#
#    survey_mode_rMove  survey_mode_rSurvey  is_participant_Selected  age_18-24  \
# 0           0.679305            -0.586502                      0.0  -0.274007
# 1           0.679305            -0.586502                      0.0  -0.274007
# 2           0.679305            -0.586502                      0.0  -0.274007
# 3           0.679305            -0.586502                      0.0  -0.274007
# 4           0.679305            -0.586502                      0.0  -0.274007
#
#    age_25-34  age_35-44  ...  disability_walking_Not selected  \
# 0   1.998608  -0.491045  ...                         0.402302
# 1   1.998608  -0.491045  ...                         0.402302
# 2  -0.500348  -0.491045  ...                         0.402302
# 3   1.998608  -0.491045  ...                         0.402302
# 4   1.998608  -0.491045  ...                         0.402302
#
#    disability_walking_Selected  disability_mobility_Not selected  \
# 0                    -0.284824                          0.297584
# 1                    -0.284824                          0.297584
# 2                    -0.284824                          0.297584
# 3                    -0.284824                          0.297584
# 4                    -0.284824                          0.297584
#
#    disability_mobility_Selected  disability_dressing_Not selected  \
# 0                     -0.131851                          0.284824
# 1                     -0.131851                          0.284824
# 2                     -0.131851                          0.284824
# 3                     -0.131851                          0.284824
# 4                     -0.131851                          0.284824
#
#    disability_dressing_Selected  disability_concentrating_Not selected  \
# 0                     -0.104355                               0.314999
# 1                     -0.104355                               0.314999
# 2                     -0.104355                               0.314999
# 3                     -0.104355                               0.314999
# 4                     -0.104355                               0.314999
#
#    disability_concentrating_Selected  disability_none_Not selected  \
# 0                          -0.163393                      -0.36141
# 1                          -0.163393                      -0.36141
# 2                          -0.163393                      -0.36141
# 3                          -0.163393                      -0.36141
# 4                          -0.163393                      -0.36141
#
#    disability_none_Selected
# 0                  0.468191
# 1                  0.468191
# 2                  0.468191
# 3                  0.468191
# 4                  0.468191
#
# [5 rows x 285 columns]

# %% [markdown]
# # Hyper Parameter Tuning

# %% [markdown]
# finding the optimal k using elbow

# %%
def elbow_method(data, model, k_range=(2, 21)):
    """
    Performs the elbow method to determine the optimal number of clusters
    for the given data and clustering model.
    
    Args:
        data (numpy.ndarray): The data to cluster
        model: The clustering model to use
        k_range (tuple): The range of k values to test (default: (2, 21))
        
    Returns:
        A tuple containing:
            - A list of sum of squared distances for each k value tested
            - The list of k values tested
    """
    result = []
    potential_k = list(range(*k_range))
    for k in potential_k:
        clustering_model = model(n_clusters=k)
        clustering_model.fit(data)
        if isinstance(clustering_model, AgglomerativeClustering):
            # Compute sum of squared distances using 'ward' linkage criterion
            distance_matrix = pdist(data)
            linkage_matrix = linkage(distance_matrix, method='ward')
            result.append(sum(np.min(linkage_matrix[:, :2], axis=1)**2))
        else:
            # Use inertia_ attribute for KMeans and other clustering models
            result.append(clustering_model.inertia_)
    return result, potential_k

agg_elbow_results, k_elbow_values = elbow_method(data_numeric_standarized, AgglomerativeClustering)

# %%
print(agg_elbow_results[0], k_elbow_values[0])
# Out:
# 19473534641.0 2

# %% [markdown]
# finding the optimal k using silhouette_score

# %%
def silhouette_method(data, model, k_range=(2, 21)):
    """
    Performs the silhouette method to determine the optimal number of clusters
    for the given data and clustering model.
    
    Args:
        data (numpy.ndarray): The data to cluster
        model: The clustering model to use
        k_range (tuple): The range of k values to test (default: (2, 21))
        
    Returns:
        A tuple containing:
            - A list of silhouette scores for each k value tested
            - The list of k values tested
    """
    result = []
    potential_k = list(range(*k_range))
    for k in potential_k:
        clustering_model = model(n_clusters=k)
        clustering_model.fit(data)
        labels = clustering_model.labels_
        result.append(silhouette_score(data, labels, metric='euclidean'))
    return result, potential_k

agg_sil_results, k_sil_values = silhouette_method(data_numeric_standarized,AgglomerativeClustering)

# %%
print(agg_sil_results[0],k_sil_values[0])
# Out:
# 0.1022582914372341 2

# %% [markdown]
# ##### plotting both

# %%
# plot for agglomerative clustering
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.plot(k_sil_values,agg_sil_results)
ax2.plot(k_elbow_values, agg_elbow_results)
ax1.set_title('silhouette_score')
ax2.set_title('Elbow Metode')
plt.show()

# %% [markdown]
# # Modeling

# %% [markdown]
# train the model with the optimal_k value

# %%
agglomerative_model = AgglomerativeClustering(distance_threshold=None,
                                n_clusters=2,
                                linkage='ward',
                                affinity='euclidean')
predicted_clusters_hierarchicaly = agglomerative_model.fit_predict(data_numeric_standarized)

# %%
np.unique(predicted_clusters_hierarchicaly)
# Out:
# array([0, 1], dtype=int64)

# %%
agg_labels = agglomerative_model.labels_
agg_labels
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# # Evaluating

# %% [markdown]
# use PCA to reduce the dimentions of the data to plot it in 2d space

# %%
# Reduce dimensionality of the data using PCA
pca = PCA(n_components=2)
X_agg_pca = pca.fit_transform(data_numeric_standarized)

# Cluster the reduced data using Agglomerative Clustering
agg = AgglomerativeClustering(n_clusters=2)
agg.fit(X_agg_pca)

# Get the cluster labels and centroids
labels = agg.labels_
centroids = pca.inverse_transform(agg.children_[0])

# Print the results
print("Cluster labels: ", labels)
print("Centroids: ", centroids)
# Out:
# Cluster labels:  [1 0 0 ... 0 0 1]
# Centroids:  [-2.33439603e+02  4.81129863e+02 -2.67736677e+01  1.89270596e+02
#  -2.54040532e+02  1.67740066e+02  1.08200481e-16  4.51052543e+01
#  -1.58752178e+02 -1.21216404e+02 -6.31578569e+01  6.58359598e+01
#   1.70256673e+02  1.67581549e+02  1.01383496e+02 -3.82437627e+02
#  -7.55192082e+01  4.81115282e+02 -3.20429875e+01 -2.68202225e+01
#  -4.81115282e+02  4.81115282e+02  4.41949745e+01 -2.52616911e+01
#  -1.90550277e+01 -5.24232385e+00 -4.27666350e+01 -3.06206353e+01
#   2.11003880e+00  2.11435436e+01 -4.44473405e+00 -1.15150389e+01
#  -6.48836928e+00 -2.12977225e+01  6.22873240e+01 -6.96881286e+01
#  -9.51192874e+01 -6.23133465e+01 -3.62149490e+01 -7.04864055e+01
#  -2.07421903e+01 -1.05953309e+02 -2.69447604e+02  4.58777098e+02
#   9.69935051e+01 -9.69935051e+01 -5.70817650e+01 -2.78170753e+02
#  -2.13264737e+01  4.34204778e+01 -1.36580645e+01 -2.35652576e+02
#  -6.95911295e+00  1.40010534e+01  4.74942796e+02 -2.11406912e+02
#  -9.22045873e+01 -1.79523637e+01 -2.04272644e+00  2.35652576e+02
#  -1.34080590e+02 -2.67141729e+01 -1.78747539e+02  2.35652576e+02
#  -5.78743856e+01 -5.84660927e+01 -1.03096078e+02 -5.17671523e+01
#  -1.83242306e+02  2.34945337e+02 -1.22650677e+02  1.29190714e+02
#  -2.81946748e+00  1.63715681e+01 -7.78791823e+00 -2.28943947e+00
#   6.95911295e+00 -1.05177129e+01 -9.69745084e+00 -4.04893589e+01
#  -1.15428870e+01 -3.57887203e+01 -8.51400115e+00  5.70817650e+01
#  -2.73298139e+01  4.50258732e+00 -7.45172484e+00 -1.00322477e+01
#  -2.74439663e+02  2.78170753e+02 -4.44473405e+00 -1.29871376e+01
#   1.36580645e+01  1.98854118e+01 -8.60007794e+00 -4.94864480e+00
#   2.13264737e+01 -3.88545385e+00  2.55746468e+01  3.80015348e+01
#  -4.34204778e+01  1.87501123e+01  2.55746468e+01  5.91462444e+00
#   1.56958074e+01  2.42907212e+01  1.21192577e+01 -4.34204778e+01
#   0.00000000e+00  0.00000000e+00 -8.76594357e+00  8.76594357e+00
#   0.00000000e+00 -7.72264501e+00  1.40142151e+01  1.32595504e+01
#  -2.83321478e-01 -2.71598664e+01  1.02419033e+01 -2.83321478e-01
#  -1.27036249e+01 -3.91253541e+00  1.19941990e+01  5.01479547e+00
#   7.97793052e-01  1.64111502e+01 -1.10230057e+01 -1.34211681e+01
#   1.75589379e+01  3.68114662e+01  5.06649283e+00 -3.31260884e+00
#   2.84589528e+01 -3.92877511e+01 -9.70613051e+00 -1.39071208e+01
#  -1.16127937e+01 -2.44075252e+00  6.26980222e+00  5.97024208e+00
#  -5.97024208e+00  0.00000000e+00  0.00000000e+00 -1.16989088e+01
#   8.22377453e+00  2.14790374e+01 -2.28955299e+01  1.73138842e+01
#   1.65494362e+01 -2.28955299e+01  0.00000000e+00  0.00000000e+00
#  -1.63571688e+02 -1.91400836e+02  3.40652416e+02 -2.13595856e+02
#  -1.41107206e+02  3.40652416e+02 -2.13280880e+02 -1.45050445e+02
#   3.40652416e+02 -1.99087865e+02 -1.57770404e+02  3.40652416e+02
#  -2.64354311e+02 -1.23248163e+02  3.40652416e+02 -1.51974556e+02
#  -1.71300896e+02  3.40652416e+02 -3.76825125e+02  1.05815870e+02
#   3.40652416e+02 -2.77603965e+02 -4.18503376e+01  3.40652416e+02
#   2.08349671e+01  1.26520067e+01  2.31543361e+01  1.79905084e+01
#   1.34454578e+01  3.65192648e+01  3.18894517e+01 -6.77670235e-01
#  -5.20842377e+01 -4.44473405e+00 -1.20267406e+01  1.26410069e+01
#   2.75771034e+01  9.48136409e+00 -2.96364549e+00 -1.57790706e+01
#  -6.22655658e+01 -1.05797374e+02 -4.73359859e+01 -3.37973279e+01
#  -2.04635155e+01 -1.32808717e+01 -1.65885273e+02  8.61705361e+00
#   2.85082386e+02  1.21400037e+01 -6.70126589e+01 -3.04457238e+01
#   1.00774213e+01 -4.34512027e+01 -1.53146326e+02 -1.09545954e+02
#  -3.30283192e+01  2.85082386e+02 -3.25913442e+01 -1.46008889e+02
#  -1.42759718e+02  2.61738368e+01  1.52659226e+01 -9.11469733e+01
#  -9.03657990e+00  3.17657797e+01  2.85082386e+02 -1.90838727e+01
#   3.12671583e-01  6.31565638e+00  1.60148592e+00 -3.61519406e+00
#   9.03657990e+00 -4.10124427e+01 -8.00101232e+01 -1.01002170e+02
#   1.42759718e+02 -2.59441653e+01 -2.26287425e+01 -1.11791373e+01
#  -1.03519386e+00 -7.70549561e+00  3.25913442e+01  7.85870689e+00
#  -1.16240055e+01 -1.65220173e+00 -1.47096037e+02  1.46008889e+02
#   1.11672445e+01  1.06346907e+01 -1.52659226e+01  2.61738368e+01
#  -2.61738368e+01  4.30976509e+00 -4.30976509e+00 -6.71478853e+00
#  -4.07152025e+00  8.57164058e+00  2.06612792e+01  1.95446845e+01
#   1.18808512e+01 -2.12990311e+01 -3.51701184e+01  2.14634927e+01
#   1.35151401e+01  3.93255398e+01  4.28149959e+01 -6.40874364e+01
#   3.19490965e+01  2.42038692e+01 -8.07381973e+01 -5.59681508e+01
#   2.06752410e+01 -6.22224219e+01  3.42767242e+01 -1.65606607e+01
#  -1.91277410e+01 -6.33075472e+01  2.78491849e+01 -2.36788417e+02
#   1.54811774e+02 -1.93123804e+02  7.54854447e+01 -3.23578236e+02
#   2.61905116e+02 -2.36459256e+02  1.66659770e+02 -2.19055584e+02
#   1.42081367e+02 -2.33339897e+02  1.49698703e+02  2.95475774e+02
#  -3.58045001e+02]

# %% [markdown]
# draw the data in 2d space

# %% [markdown]
# #### using PCA

# %%
# Plot the clustered data "agglomerative"
plt.scatter(X_agg_pca[:, 0], X_agg_pca[:, 1], c=labels, cmap='rainbow')
plt.title('Agglomerative Clustering with PCA')
plt.show()

# %% [markdown]
# #### using UMAP

# %%
def plot_cluster_results(data, n_clusters, algorithm):
    # cluster the data
    if algorithm == 'kmeans':
        model = KMeans(n_clusters=n_clusters)
    elif algorithm == 'agglomerative':
        model = AgglomerativeClustering(n_clusters=n_clusters)
    else:
        print('Unsupported algorithm.')
        return
    
    cluster_labels = model.fit_predict(data)
    
    # reduce the dimensionality of the data using UMAP
    reducer = umap.UMAP(n_components=2)
    umap_model = reducer.fit(data)
    training_data_embedding = umap_model.transform(data)
    
    # get the cluster centers
    if algorithm == 'kmeans':
        centers = model.cluster_centers_
    else:
        centers = []
        for i in range(n_clusters):
            centers.append(data[cluster_labels == i].mean(axis=0))
        centers = np.array(centers)
    
    centers_embedding = umap_model.transform(centers)
    
    # plot the data in the low dim with the cluster results
    plt.scatter(training_data_embedding[:, 0], training_data_embedding[:, 1],
                c=cluster_labels, s=50, cmap='viridis')
    plt.scatter(centers_embedding[:, 0], centers_embedding[:, 1],
                c='red', s=200, alpha=0.5)
    plt.show()

# %%
plot_cluster_results(data_numeric_standarized, n_clusters=2,  algorithm='agglomerative')

# %%
pca = PCA(n_components=3)
pca.fit(data_numeric_standarized)
pca_bcancer = pca.transform(data_numeric_standarized)
pca_centers = pca.transform(agg_labels)
print(agg_labels)
print(pca_centers)
cdict = {0:'m',1:'c',2:'g',3:'y'}
label = {0:'0',1:'1',2:"2",3:"3"}
y = predicted_clusters_hierarchicaly.reshape(-1,1)

Xax = pca_bcancer[:,0]
Yax = pca_bcancer[:,1]
Zax = pca_bcancer[:,2]

fig = plt.figure(figsize=(14,9))
ax = fig.add_subplot(111, 
                     projection='3d')
 
for l in np.unique(y):
 ix=np.where(y==l)
 ax.scatter(Xax[ix], 
            Yax[ix], 
            Zax[ix], 
            c=cdict[l], 
            s=60,
           label=label[l])
 


ax.set_xlabel("PC1", 
              fontsize=12)
ax.set_ylabel("PC2", 
              fontsize=12)
ax.set_zlabel("PC3", 
              fontsize=12)
 
ax.view_init(30, 125)
ax.legend()
plt.title("3D PCA plot")
plt.show()
# Out:
# C:\Users\danar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [106], line 4
#       2 pca.fit(data_numeric_standarized)
#       3 pca_bcancer = pca.transform(data_numeric_standarized)
# ----> 4 pca_centers = pca.transform(agg_labels)
#       5 print(agg_labels)
#       6 print(pca_centers)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\decomposition\_base.py:120, in _BasePCA.transform(self, X)
#     101 """Apply dimensionality reduction to X.
#     102
#     103 X is projected on the first principal components previously extracted
#    (...)
#     116     is the number of samples and `n_components` is the number of the components.
#     117 """
#     118 check_is_fitted(self)
# --> 120 X = self._validate_data(X, dtype=[np.float64, np.float32], reset=False)
#     121 if self.mean_ is not None:
#     122     X = X - self.mean_
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:577, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     575     raise ValueError("Validation should be done on X, y or both.")
#     576 elif not no_val_X and no_val_y:
# --> 577     X = check_array(X, input_name="X", **check_params)
#     578     out = X
#     579 elif no_val_X and not no_val_y:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877     # If input is 1D raise error
#     878     if array.ndim == 1:
# --> 879         raise ValueError(
#     880             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     881             "Reshape your data either using array.reshape(-1, 1) if "
#     882             "your data has a single feature or array.reshape(1, -1) "
#     883             "if it contains a single sample.".format(array)
#     884         )
#     886 if dtype_numeric and array.dtype.kind in "USV":
#     887     raise ValueError(
#     888         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     889         "Convert your data to numeric values explicitly instead."
#     890     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[1. 0. 0. ... 0. 0. 0.].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
